# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.chdir("..")

# %%
for i in range(10):
    path = "data/testcases/" + str(i) + ".png"
    image = cv2.imread(path)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
from main import run_pipeline

# %%
results = []

for i in range(10):
    path = "data/testcases/" + str(i) + ".png"
    original, result = run_pipeline(path)
    results.append(result)

for i in range(10):
    plt.imshow(cv2.cvtColor(results[i], cv2.COLOR_BGR2RGB))
    plt.show()

# %%
import numpy as np

def extract_predicted_boundary_mask(result_image):

    red = result_image[:,:,2]
    green = result_image[:,:,1]
    blue = result_image[:,:,0]

    mask = np.zeros(red.shape, dtype=np.uint8)

    mask[(red > 150) & (green < 100) & (blue < 100)] = 1

    return mask

# %%
scores = []

for i in range(10):

    pred_img = results[i]
    pred_mask = extract_predicted_boundary_mask(pred_img)

    gt = cv2.imread(f"data/ground_truth_masks/{i}.png", 0)
    gt = cv2.resize(gt, (256,256))

    gt_mask = (gt > 10).astype(np.uint8)

    kernel = np.ones((3,3), np.uint8)
    gt_mask = cv2.dilate(gt_mask, kernel)

    intersection = np.sum(pred_mask * gt_mask)
    total_pred = np.sum(pred_mask)

    score = 0 if total_pred == 0 else intersection / total_pred

    print(f"Image {i} Score:", round(score,4))
    scores.append(score)

print("Average Boundary Score:", round(sum(scores)/len(scores),4))
# Out:
# Image 0 Score: 0.3887
# Image 1 Score: 0.5229
# Image 2 Score: 0.9727
# Image 3 Score: 0.2242
# Image 4 Score: 0.6504
# Image 5 Score: 0.8424
# Image 6 Score: 0.7854
# Image 7 Score: 0.7415
# Image 8 Score: 0.7241
# Image 9 Score: 0.5965
# Average Boundary Score: 0.6449
